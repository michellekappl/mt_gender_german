# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# concat all stats
def concat_stats(model, lang):
    n = pd.read_csv(f'../../../data/human/{model}/{lang}/none/{lang}.pred_stats.csv')
    a = pd.read_csv(f'../../../data/human/{model}/{lang}/anti/{lang}.pred_stats.csv')
    p = pd.read_csv(f'../../../data/human/{model}/{lang}/pro/{lang}.pred_stats.csv')
    aw = pd.read_csv(f'../../../data/human/{model}/{lang}/anti_wmt/{lang}.pred_stats.csv')
    pw = pd.read_csv(f'../../../data/human/{model}/{lang}/pro_wmt/{lang}.pred_stats.csv')

    stats = pd.DataFrame([n.mean(axis=0), a.mean(axis=0), p.mean(axis=0), aw.mean(axis=0), pw.mean(axis=0)])
    acc_wo_unk = n.mean(axis=0)['acc'] * (n.mean(axis=0)['pred_m'] + n.mean(axis=0)['pred_f'] + n.mean(axis=0)['pred_n'])/ (n.mean(axis=0)['pred_m'] + n.mean(axis=0)['pred_f'] - n.mean(axis=0)['unk_m'] - n.mean(axis=0)['unk_f'] + n.mean(axis=0)['pred_n'])
    new_row = [f'{model}_{lang}', n.mean(axis=0)['acc'], (n.mean(axis=0)['f1_m']-n.mean(axis=0)['f1_f']), (p.mean(axis=0)['acc']-a.mean(axis=0)['acc']), (pw.mean(axis=0)['acc']-aw.mean(axis=0)['acc']), ((n.mean(axis=0)['unk_f'] + n.mean(axis=0)['unk_m'])/288)*100, acc_wo_unk]

    stats.insert(0, 'stereotype', [f'{model}_{lang}', 'anti', 'pro', 'anti_wmt', 'pro_wmt'])

    return stats, new_row
    
file_exists = os.path.isfile('pred_stats.csv')

table = []
with open(f'./pred_stats.csv', 'w') as f:
    for model in ['gpt4o-mini']:
        for lang in ['it', 'fr', 'uk', 'ru', 'es', 'he', 'ar']:
            stats,row = concat_stats(model, lang)
            table.append(row)
            if file_exists:
                stats.to_csv('./pred_stats.csv', mode='a', index=False, header=None)
            else:
                stats.to_csv('./pred_stats.csv', mode='a', index=False)
                file_exists = True

new_df = pd.DataFrame(table, columns=['stereotype', 'acc', 'delta-G', 'delta-S', 'delta-S_wmt', 'unk_perc', 'acc_wo_unk'])
new_df = new_df.round(1)
print(new_df['delta-G'].mean())
new_df.to_csv('./table.csv', mode='a', index=False)
# Out:
# 2.4428571428571426

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
def concat_job_stats(model, lang):
    n = pd.read_csv(f'../../../data/human/{model}/{lang}/none/{lang}.pred.csv', names=['translated_professions','target_indices','target_sentences','gender_prediction','ds'])
    a = pd.read_csv(f'../../../data/human/{model}/{lang}/anti/{lang}.pred.csv', names=['translated_professions','target_indices','target_sentences','gender_prediction','ds'])
    p = pd.read_csv(f'../../../data/human/{model}/{lang}/pro/{lang}.pred.csv', names=['translated_professions','target_indices','target_sentences','gender_prediction','ds'])
    aw = pd.read_csv(f'../../../data/human/{model}/{lang}/anti_wmt/{lang}.pred.csv', names=['translated_professions','target_indices','target_sentences','gender_prediction','ds'])
    pw = pd.read_csv(f'../../../data/human/{model}/{lang}/pro_wmt/{lang}.pred.csv', names=['translated_professions','target_indices','target_sentences','gender_prediction','ds'])
 
    jobs = pd.read_csv('./statistics_dataset/job_data_dataset_.csv', sep=',', names=['job','gender','2cnd','idx','ab_code','job_class','total','perc','stereotype'])
    n = n.tail(-1)
    a = a.tail(-1)
    p = p.tail(-1)
    aw = aw.tail(-1)
    pw = pw.tail(-1)

    n_jobs_temp = [item.strip('[').strip(']').split("', '")[3].strip("'") for idx,item in n['ds'].items()]
    n_gender_temp = [item.strip('[').strip(']').split("', '")[0].strip("'") for idx,item in n['ds'].items()]

    a_jobs_temp = [item.strip('[').strip(']').split("', '")[3].strip("'") for idx,item in a['ds'].items()]
    a_gender_temp = [item.strip('[').strip(']').split("', '")[0].strip("'") for idx,item in a['ds'].items()]

    p_jobs_temp = [item.strip('[').strip(']').split("', '")[3].strip("'") for idx,item in p['ds'].items()]
    p_gender_temp = [item.strip('[').strip(']').split("', '")[0].strip("'") for idx,item in p['ds'].items()]

    aw_jobs_temp = [item.strip('[').strip(']').split("', '")[3].strip("'") for idx,item in aw['ds'].items()]
    aw_gender_temp = [item.strip('[').strip(']').split("', '")[0].strip("'") for idx,item in aw['ds'].items()]

    pw_jobs_temp = [item.strip('[').strip(']').split("', '")[3].strip("'") for idx,item in pw['ds'].items()]
    pw_gender_temp = [item.strip('[').strip(']').split("', '")[0].strip("'") for idx,item in pw['ds'].items()]

    n_jobs = pd.DataFrame([n_jobs_temp, n_gender_temp, n['gender_prediction']]).T
    a_jobs = pd.DataFrame([a_jobs_temp, a_gender_temp, a['gender_prediction']]).T
    p_jobs = pd.DataFrame([p_jobs_temp, p_gender_temp, p['gender_prediction']]).T
    aw_jobs = pd.DataFrame([aw_jobs_temp, aw_gender_temp, aw['gender_prediction']]).T
    pw_jobs = pd.DataFrame([pw_jobs_temp, pw_gender_temp, pw['gender_prediction']]).T
 
    for idx, row in n_jobs.iterrows():
        job_temp = jobs[jobs['job'] == row[0]]['job_class']
        n_jobs.loc[idx, 'job_class'] = job_temp.values[0]

    for idx, row in a_jobs.iterrows():
        job_temp = jobs[jobs['job'] == row[0]]['job_class']
        a_jobs.loc[idx, 'job_class'] = job_temp.values[0]
    
    for idx, row in p_jobs.iterrows():
        job_temp = jobs[jobs['job'] == row[0]]['job_class']
        p_jobs.loc[idx, 'job_class'] = job_temp.values[0]
    
    for idx, row in aw_jobs.iterrows():
        job_temp = jobs[jobs['job'] == row[0]]['job_class']
        aw_jobs.loc[idx, 'job_class'] = job_temp.values[0]

    for idx, row in pw_jobs.iterrows():
        job_temp = jobs[jobs['job'] == row[0]]['job_class']
        pw_jobs.loc[idx, 'job_class'] = job_temp.values[0]
    
    return n_jobs, a_jobs, p_jobs, aw_jobs, pw_jobs

# for model in ['bing', 'google', 'systran', 'aws']:
#     for lang in ['it', 'fr', 'uk', 'ru', 'es', 'he', 'ar']:
#         n,a,p,aw,pw = concat_job_stats(model, lang)
#         n.to_csv(f'../data/pred_job_stats_{model}.csv', mode='a', index=False, header=None)
# for lang in ['it', 'fr', 'uk', 'ru', 'es']:
#     n,a,p,aw,pw = concat_job_stats('deepl',lang)
#     n.to_csv(f'../data/pred_job_stats_deepl.csv', mode='a', index=False, header=None)

# for lang in ['it', 'fr', 'es']:
#     n,a,p,aw,pw = concat_job_stats('bing', lang)
#     n.to_csv(f'../data/pred_job_stats_romance_bing.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('deepl', lang)
#     n.to_csv(f'../data/pred_job_stats_romance_deepl.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('systran', lang)
#     n.to_csv(f'../data/pred_job_stats_romance_systran.csv', mode='a', index=False, header=None)


# for lang in ['uk', 'ru']:
#     n,a,p,aw,pw = concat_job_stats('bing', lang)
#     n.to_csv(f'../data/pred_job_stats_sla_bing.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('deepl', lang)
#     n.to_csv(f'../data/pred_job_stats_sla_deepl.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('systran', lang)
#     n.to_csv(f'../data/pred_job_stats_sla_systran.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('aws', lang)
#     n.to_csv(f'../data/pred_job_stats_sla_aws.csv', mode='a', index=False, header=None)
#     n,a,p,aw,pw = concat_job_stats('google', lang)
#     n.to_csv(f'../data/pred_job_stats_sla_google.csv', mode='a', index=False, header=None)

for lang in ['it', 'fr', 'es']:
    n,a,p,aw,pw = concat_job_stats('gpt4o-mini', lang)
    n.to_csv(f'./job_instances/pred_jobs/pred_job_stats_romance_gpt4o-mini.csv', mode='a', index=False, header=None)

for lang in ['uk', 'ru']:
    n,a,p,aw,pw = concat_job_stats('gpt4o-mini', lang)
    n.to_csv(f'./job_instances/pred_jobs/pred_job_stats_sla_gpt4o-mini.csv', mode='a', index=False, header=None)
    

    # a.to_csv(f'../data/pred_job_stats_deepl.csv', mode='a', index=False)
    # p.to_csv(f'../data/pred_job_stats_deepl.csv', mode='a', index=False)
    # aw.to_csv(f'../data/pred_job_stats_deepl.csv', mode='a', index=False)
    # pw.to_csv(f'../data/pred_job_stats_deepl.csv', mode='a', index=False)

# %%
import seaborn as sns
import scipy.stats as sp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

names = ['Microsoft Translate', 'Google Translate', 'SYSTRAN', 'Amazon Translate', 'DeepL']
for i, mt in enumerate(['bing', 'google', 'systran', 'aws', 'deepl']):
    df = pd.read_csv(f'../statistics/job_instances/pred_{mt}_job_stats.csv')
    df.sort_values(by=['ab_code'], inplace=True)

    df['female_perc'] = df['female'] / (df['male'] + df['female']) * 100
    df['male_perc'] = df['male'] / (df['male'] + df['female']) * 100

    bar_min = 20
    bar_max = 80
    alpha = 0.3

    filtered_df_f = df[(df['gold_female_perc'] > bar_max) | (df['gold_female_perc'] < bar_min)].dropna()
    filtered_df_m = df[(df['gold_male_perc'] > bar_max) | (df['gold_male_perc'] < bar_min)].dropna()

    print(mt)
    print('female:')
    print(df['gold_female_perc'].corr(df['female_perc']))
    print(filtered_df_f['gold_female_perc'].corr(filtered_df_f['female_perc']))

    gender_markers = {
    'Female': 'o',  # Circle for Female
    'Male': 'x',    # X for Male
    }

    num_job_classes = 46

    # Create a colormap with distinct colors
    cmap = plt.get_cmap('turbo')  # You can choose a different colormap if you prefer

    # Generate a list of distinct colors for each job class
    job_class_colors = [cmap(i) for i in np.linspace(0, 1, num_job_classes)]

    # Create a figure and axis
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))
    
    pl1 = ax1.scatter(y=df['male_perc'], x=df['gold_male_perc'], c= job_class_colors, alpha=np.where((df['gold_male_perc'] >= bar_min) & (df['gold_male_perc'] <= bar_max), alpha, 1.0), label='Male', marker='x')
    pl2 = ax2.scatter(y=df['female_perc'], x= df['gold_female_perc'],c= job_class_colors,alpha=np.where((df['gold_female_perc'] >= bar_min) & (df['gold_female_perc'] <= bar_max), alpha, 1.0), marker='o', )

    ax1.set_yticks(np.arange(0, 101, 20))
    ax1.set_ylim(ymin=-5, ymax=105)
    ax1.set_xlim(xmin=-5, xmax=105)
    ax2.set_yticks(np.arange(0, 101,20))
    ax2.set_ylim(ymin=-5, ymax=105)
    ax2.set_xlim(xmin=-5, xmax=105)

    # Adding labels and title
    ax1.set_xlabel('Gold Distribution in %')
    ax2.set_xlabel('Gold Distribution in %')
    ax1.set_ylabel('Dataset Distribution in %')
    ax2.set_ylabel('Dataset Distribution in %')
    ax1.set_title('Male Job Instances')
    ax2.set_title('Female Job Instances')
    ax1.grid(True)
    ax2.grid(True)

    ab_code_to_color = dict(zip(df['ab_code'], job_class_colors))
    # Create legend handles and labels for each ab_code
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=ab_code, 
                                markerfacecolor=color, markersize=10)
                    for ab_code, color in ab_code_to_color.items()]

    # Add the legend to the plot
    fig.legend(handles=legend_handles, title='AB Codes', loc='center left', fontsize='small', ncol=3, bbox_to_anchor=(0.915, 0.49))
    fig.suptitle(f'Predicted Job Instances for {names[i]}')

    fig.show()

    fig.savefig(f'../data/figures/pred_{mt}_job_stats.png', bbox_inches='tight')

    #df.to_csv(f'../data/job_instances/pred_{mt}_job_stats.csv', index=False)
# Out:
# bing
# female:
# 0.3773185441907048
# 0.47572799258719783
# /var/folders/10/gpm1mn557dq4z3fzgrpvk2700000gn/T/ipykernel_4355/1414781210.py:73: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 75
#      71 fig.suptitle(f'Predicted Job Instances for {names[i]}')
#      73 fig.show()
# ---> 75 fig.savefig(f'../data/figures/pred_{mt}_job_stats.png', bbox_inches='tight')
#      77 #df.to_csv(f'../data/job_instances/pred_{mt}_job_stats.csv', index=False)
#
# File ~/.pyenv/versions/3.8.17/envs/ba/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
# ...

# %%
import seaborn as sns
import scipy.stats as sp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

fig, ax1 = plt.subplots(1, figsize=(9,9))
names = ['Microsoft Translator', 'Google Translate', 'SYSTRAN', 'Amazon Translate', 'DeepL', 'GPT-4o-mini']
df_perc = pd.DataFrame()

for i, mt in enumerate(['bing', 'google', 'systran', 'aws', 'deepl', 'gpt4o-mini']):
    df = pd.read_csv(f'../statistics/job_instances/pred_{mt}_job_stats.csv')
    df.sort_values(by=['ab_code'], inplace=True)

    df['gold_male_perc'] = df['gold_male_perc'] - 50
    df['male_perc'] = df['male'] / (df['male'] + df['female']) * 100
    df['male_perc'] = df['male_perc'] - 50
    
    if i == 0:
        df_perc['male_perc'] = df['male_perc']
    df_perc['male_perc'] = df_perc['male_perc'] + df['male_perc']

    mt_markers = {
    'bing': 'o',
    'google': 'p',
    'systran': 'd',
    'aws': 'v',
    'deepl': 's',
    'gpt4o-mini': 'X'
    }

    num_job_classes = 46

    # Create a colormap with distinct colors
    cmap = plt.get_cmap('turbo')  # You can choose a different colormap if you prefer

    # Generate a list of distinct colors for each job class
    job_class_colors = [cmap(i) for i in np.linspace(0, 1, num_job_classes)]

    # Create a figure and axis    
    ax1.scatter(y=df['male_perc'], x=df['gold_male_perc'], c= job_class_colors, marker=mt_markers[mt], s = 90, edgecolors='grey')

ax1.set_ylim(ymin=-51, ymax=51)
ax1.set_xlim(xmin=-51, xmax=51)

ax1.set_xticks([-50, -25, 0, 25, 50])
ax1.set_xticklabels(['100', '75', '50/50', '75', '100'])
fig.text(0.3, 0.065, 'female')
fig.text(0.685, 0.065, 'male')

ax1.set_yticks([-50, -25, 0, 25, 50])
ax1.set_yticklabels(['100', '75', '50/50', '75', '100'], rotation='vertical')
ax1.axvline(25, c='grey', lw=0.5, ls='dashed')
ax1.axvline(-25, c='grey', lw=0.5, ls='dashed')
ax1.axhline(25, c='grey', lw=0.5, ls='dashed')
ax1.axhline(-25, c='grey', lw=0.5, ls='dashed')
fig.text(0.08, 0.285, 'female', rotation='vertical')
fig.text(0.08, 0.665, 'male', rotation='vertical')

ax1.axvline(0, c='k', lw=2)
ax1.axhline(0, c='darkgreen', lw=2)
ax1.fill_between([-100,100], -5,5, facecolor='darkgreen', alpha=0.1)
ax1.fill_betweenx([-100,100],-5,5, facecolor='grey', alpha=0.2)

# Adding labels and title
ax1.set_ylabel('Gender Distribution within Translation (in %)', labelpad=15)
ax1.set_xlabel('Real World Distribution (in %)', labelpad=15)
ax1.spines[['right', 'top']].set_visible(False)

fig.text(0.25, 0.8, 'stereotypically female\nwith male translation', ha='center', va='center', fontsize=10, bbox=dict(facecolor='white', edgecolor='black', alpha=0.5, boxstyle='round,pad=0.5'))
fig.text(0.25, 0.2, 'stereotypically female\nwith female translation', ha='center', va='center', fontsize=10, bbox=dict(facecolor='white', edgecolor='black', alpha=0.5, boxstyle='round,pad=0.5'))

fig.text(0.65, 0.2, 'stereotypically male\nwith female translation', ha='center', va='center', fontsize=10, bbox=dict(facecolor='white', edgecolor='black', alpha=0.5, boxstyle='round,pad=0.5'))
fig.text(0.65, 0.8, 'stereotypically male\nwith male translation', ha='center', va='center', fontsize=10, bbox=dict(facecolor='white', edgecolor='black', alpha=0.5, boxstyle='round,pad=0.5'))

fig.text(0.7, 0.493, 'Perfect\nTranslation', ha='center', va='center', fontsize=10, color='darkgreen')
fig.text(0.514, 0.3, 'Balanced\nGender Distribution', ha='center', va='center', fontsize=10, color='k', rotation='vertical')


ab_code_to_color = dict(zip(df['ab_code'], job_class_colors))
stat = pd.read_csv('../job_data_arbeitsamt_with_short.csv')

# Create legend handles and labels for each ab_code
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=stat.ab_code[i], 
                            markerfacecolor=ab_code_to_color[color], markersize=10)
                for i, color in enumerate(ab_code_to_color)]

legend_handles2 = [plt.Line2D([0], [0], marker=mt_markers[mt], color='w', label=names[i], 
                            markerfacecolor='k', markersize=5)
                for i,mt in enumerate(mt_markers)]
# # Add the legend to the plot
fig.legend(handles=legend_handles, title='Code', fontsize='small', ncol=2, loc='center left',bbox_to_anchor=(0.91, 0.55))
fig.legend(handles=legend_handles2, title='MT Models', loc='center left', fontsize='small', ncol=1, bbox_to_anchor=(0.91, 0.2))
fig.show()

fig.savefig(f'../data/figures/pred_{mt}_job_stats_.png', bbox_inches='tight')

    #df.to_csv(f'../data/job_instances/pred_{mt}_job_stats.csv', index=False)
# Out:
# /var/folders/10/gpm1mn557dq4z3fzgrpvk2700000gn/T/ipykernel_75726/2996680834.py:94: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 96
#      93 fig.legend(handles=legend_handles2, title='MT Models', loc='center left', fontsize='small', ncol=1, bbox_to_anchor=(0.91, 0.2))
#      94 fig.show()
# ---> 96 fig.savefig(f'../data/figures/pred_{mt}_job_stats_.png', bbox_inches='tight')
#      98     #df.to_csv(f'../data/job_instances/pred_{mt}_job_stats.csv', index=False)
#
# File ~/.pyenv/versions/3.8.17/envs/ba/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def calc_perc(df, gender):
    return pivot_df[gender] / pivot_df['total_sum'] * 100    

#names = ['Google Translate', 'Amazon Translate']
names = ['GPT-4o-mini', 'SYSTRAN', 'DeepL']
fig, ax_all = plt.subplots(3,1, figsize= (16,16))
#fig, ax_all = plt.subplots(2,1, figsize= (16,12))

fig.tight_layout(pad=6)

#for i, mt in enumerate(['google', 'aws']):
for i, mt in enumerate(['gpt4o-mini', 'systran', 'deepl']):
    df = pd.read_csv(f'../statistics/job_instances/pred_jobs/pred_job_stats_{mt}_grouped.csv')
    #df = pd.read_csv(f'../statistics/job_instances/pred_jobs/pred_job_stats_romance_{mt}_grouped.csv')
    df.rename(columns={'job_class': 'name'}, inplace=True)
    ab_code = pd.read_csv('../job_data_arbeitsamt_with_short.csv')
    ab_code = ab_code[['ab_code', 'name']]

    pivot_df = df.pivot_table(index='name', columns=['gold_gender', 'pred_gender'], values='count', fill_value=0)
    # Flatten the multi-level columns
    pivot_df.columns = [f'count_{gold}_{pred}' for gold, pred in pivot_df.columns]
    # Reset the index to have 'name' as a column

    pivot_df.reset_index(inplace=True)
    pivot_df = pivot_df.merge(ab_code, on='name')

    pivot_df['total_sum'] = pivot_df.iloc[:, 1:-1].sum(axis=1)

    pivot_df['all_male'] = pivot_df['count_female_GENDER.male']+pivot_df['count_male_GENDER.male']
    pivot_df['all_unknown']= pivot_df['count_female_GENDER.unknown']+pivot_df['count_male_GENDER.unknown']
    pivot_df['all_neutral']= pivot_df['count_female_GENDER.neutral']+pivot_df['count_male_GENDER.neutral']
    pivot_df['all_female'] = pivot_df['count_female_GENDER.female']+pivot_df['count_male_GENDER.female']
    pivot_df['male_perc'] = calc_perc(pivot_df, 'all_male')
    pivot_df['female_perc'] = calc_perc(pivot_df, 'all_female')

    pivot_df = pivot_df.sort_values(by=['female_perc'])
    ###### PLOT 1 ######
    x = pivot_df['ab_code']
    #plt.subplots_adjust(hspace=0.15)

    mm = calc_perc(pivot_df, 'count_male_GENDER.male')
    mf = calc_perc(pivot_df, 'count_male_GENDER.female')
    mn = calc_perc(pivot_df, 'count_male_GENDER.neutral')
    mu = calc_perc(pivot_df, 'count_male_GENDER.unknown')
    ff = calc_perc(pivot_df, 'count_female_GENDER.female')
    fm = calc_perc(pivot_df, 'count_female_GENDER.male')
    fn = calc_perc(pivot_df, 'count_female_GENDER.neutral')
    fu = calc_perc(pivot_df, 'count_female_GENDER.unknown')

    colour_dict_ = {
        'mm': '#16169e',
        'mf': '#af3f27',
        'mn': '#c3d3a5',
        'mu': '#f8ffde',
        'fu': '#ffe6d9',
        'fn': '#efb19f',
        'fm': '#7d65bb',
        'ff': '#960500',
        'n': '#ffe600',
        'u': '#ffa640'
    }

    colour_dict = {
        'mm': '#f5793a',
        'fm': '#f79361',
        'mf': '#b16aaa',
        'ff': '#874880',
        'u': '#9dccfa',
        'n': '#eeeeee'
    }

    ax = ax_all[i]
    ax.bar(x,100, color = '#000000', edgecolor='#000000')
    ax.bar(x, ff, color=colour_dict['ff'], label='true female')
    ax.bar(x, mf, bottom=ff, color=colour_dict['mf'], label='false female')
    ax.bar(x, mm, bottom=ff+mf, color=colour_dict['mm'], label='true male')
    ax.bar(x, fm, bottom=mm+ff+mf, color=colour_dict['fm'],edgecolor=colour_dict['mm'] ,label='false male')
    ax.bar(x, mu, bottom=mm+ff+fm+mf, color=colour_dict['u'],hatch='/', edgecolor= colour_dict['mm'], label='unknown (was male)')
    ax.bar(x, fu, bottom=mm+ff+fm+mf+mu, color=colour_dict['u'],hatch='\\', edgecolor= colour_dict['ff'], label='unknown (was female)')
    ax.bar(x, mn, bottom=mm+ff+fm+mf+fu+mu,color=colour_dict['n'], hatch='/', edgecolor=colour_dict['mm'], label='neutral (was male)')
    ax.bar(x, fn, bottom=mm+ff+fm+mf+fu+mu+mn, color=colour_dict['n'], hatch='\\', edgecolor= colour_dict['ff'], label='neutral (was female)')


    ax.set_ylabel('Share in %', fontsize=15)
    ax.set_xticks(x,pivot_df['ab_code'], rotation=90, fontsize=13)
    ax.set_xlim(-1, 46)
    ax.set_yticks(np.arange(0, 100, 10))
    ax.set_ylim(0,100)
    ax.xaxis.set_label_coords(1, -0.06)
    ax.axhline(50, c='k', lw=1)
    
    if i == 0:
        fig.legend(title='Gender Prediction of Translation', loc='upper center', bbox_to_anchor=(0.505,1), ncol=8, framealpha=1)

    ax.set_title(f'Gender Distribution for {names[i]}', y=1)
    #ax.set_title(f'Predicted Job Instances for {names[i]} within the Romance language family', y=1)
    
plt.savefig(f'../data/figures/pred_all_job_stats_grouped_romance_chat.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 102
#      99     ax.set_title(f'Gender Distribution for {names[i]}', y=1)
#     100     #ax.set_title(f'Predicted Job Instances for {names[i]} within the Romance language family', y=1)
# --> 102 plt.savefig(f'../data/figures/pred_all_job_stats_grouped_romance_chat.png', bbox_inches='tight')
#
# File ~/.pyenv/versions/3.8.17/envs/ba/lib/python3.8/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# ...

# %%
import seaborn as sns
import scipy.stats as sp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


names = ['gpt4o-mini']
for i, mt in enumerate(names):
    df = pd.read_csv(f'./job_instances/pred_jobs/pred_job_stats_romance_{mt}.csv', names= ['name', 'gold_gender', 'pred_gender', 'job_class'])

    grouped_df = df.groupby(["job_class", "gold_gender", 'pred_gender']).size().reset_index(name="count")
    ab_codes = pd.read_csv('../job_data_arbeitsamt_with_short.csv')
    ab_codes = ab_codes.rename(columns={'name':'job_class'})
    ab_codes = ab_codes[['job_class', 'ab_code']]
    grouped = grouped_df.merge(ab_codes, on='job_class')

    grouped['total_count'] = grouped.groupby(['ab_code', 'gold_gender'])['count'].transform('sum')
    # Calculate the percentage with respect to 'gold_female' and 'gold_male' 
    grouped['perc'] = ((grouped['count'] / grouped['total_count']) * 100)/2

    no_neutral = grouped.groupby(['ab_code','gold_gender'])['pred_gender'].apply(lambda x: 'GENDER.neutral' not in x.values)
    no_unknown = grouped.groupby(['ab_code','gold_gender'])['pred_gender'].apply(lambda x:'GENDER.unknown' not in x.values)
    no_male = grouped.groupby(['ab_code','gold_gender'])['pred_gender'].apply(lambda x:'GENDER.male' not in x.values)
    no_female = grouped.groupby(['ab_code','gold_gender'])['pred_gender'].apply(lambda x:'GENDER.female' not in x.values)

    to_add = []
    for idx, (jc, gg, pg, cnt, ab, tc, perc) in grouped.iterrows():
        if no_neutral[ab][gg] == True:
            to_add.append([jc,gg, 'GENDER.neutral',0, ab, 0, 0])
        if no_unknown[ab][gg] == True:
            to_add.append([jc,gg,'GENDER.unknown',0, ab, 0, 0])
        if no_male[ab][gg] == True:
            to_add.append([jc,gg,'GENDER.male',0, ab, 0, 0])
        if no_female[ab][gg] == True:
            to_add.append([jc,gg,'GENDER.female',0, ab, 0, 0])
    
    to_add_df = pd.DataFrame(to_add)
    to_add_df.columns = grouped.columns
    to_add_df = to_add_df.drop_duplicates().reset_index(drop=True)
    print(grouped)

    grouped = pd.concat([grouped, to_add_df]).sort_values(by=['ab_code', 'gold_gender'])
    grouped.to_csv(f'./job_instances/pred_jobs/pred_job_stats_romance_{mt}_grouped.csv', index=False)

        
    x = np.arange(len(grouped['ab_code'].unique()))

    m = grouped[grouped['gold_gender'] == 'male']
    mmale = m[m['pred_gender']=='GENDER.male'].reset_index(drop=True)
    mfemale = m[m['pred_gender']=='GENDER.female'].reset_index(drop=True)
    munknown = m[m['pred_gender']=='GENDER.unknown'].reset_index(drop=True)
    mneutral = m[m['pred_gender']=='GENDER.neutral'].reset_index(drop=True)

    f = grouped[grouped['gold_gender'] == 'female']
    fmale = f[f['pred_gender']=='GENDER.male'].reset_index(drop=True)
    ffemale = f[f['pred_gender']=='GENDER.female'].reset_index(drop=True)
    funknown = f[f['pred_gender']=='GENDER.unknown'].reset_index(drop=True)
    fneutral = f[f['pred_gender']=='GENDER.neutral'].reset_index(drop=True)

    fig, (ax,ax1) = plt.subplots(2,1, figsize= (18,13), sharex = ax1, gridspec_kw={'height_ratios': [2, 1]}) 
    plt.subplots_adjust(hspace=0.09)

    ax.bar(x, 50, color='#000000', edgecolor='black')
    ax.bar(x, 100, color='#000000', edgecolor='black')

    ax.bar(x, mmale['perc'], color='#355400', label='male-male')
    ax.bar(x, mfemale['perc'], bottom=mmale['perc'], color='#7b9153',label='male-female')
    ax.bar(x, munknown['perc'], bottom=mmale['perc']+mfemale['perc'], color='#c3d3a5', label='male-unknown')
    ax.bar(x, mneutral['perc'], bottom=mmale['perc']+mfemale['perc']+munknown['perc'], color='#f8ffde', label='male-neutral')
    ax.bar(x, ffemale['perc'], bottom=mmale['perc']+mfemale['perc']+munknown['perc']+mneutral['perc'],color='#960500', label='female-female')
    ax.bar(x, fmale['perc'], bottom=mmale['perc']+mfemale['perc']+munknown['perc']+mneutral['perc']+ffemale['perc'], color='#c7664d', label='female-male')
    ax.bar(x, funknown['perc'], bottom=mmale['perc']+mfemale['perc']+munknown['perc']+mneutral['perc']+fmale['perc']+ffemale['perc'], color='#efb19f', label='female-unknown')
    ax.bar(x, fneutral['perc'], bottom=mmale['perc']+mfemale['perc']+munknown['perc']+mneutral['perc']+fmale['perc']+ffemale['perc']+funknown['perc'], color='#ffe6d9', label='female-neutral')

    ax1.set_ylabel('Percentage in %', fontsize=15)
    ax1.set_title(f'Prediction Distribution for {names[i]}', fontsize=15)    
    ax1.set_xticks(x, grouped['ab_code'].unique(), rotation=90, fontsize=12)
    ax1.set_yticks(np.arange(0, 100, 10))
    ax1.set_ylim(0,100)
    ax1.legend(title='gender before translation - prediction', loc='center left', bbox_to_anchor=(0.96, 0.5), ncol=1, framealpha=1)
    ax1.set_xlabel('AB Codes', fontsize=12)
    ax1.xaxis.set_label_coords(1, -0.02)

    all = grouped.groupby(['ab_code', 'pred_gender'])['perc'].sum().reset_index(name="total_perc")
    print(all)


    male = all[all['pred_gender'] == 'GENDER.male'].reset_index(drop=True).sort_values(by=['total_perc'])
    female = all[all['pred_gender'] == 'GENDER.female'].reset_index(drop=True).sort_values(by=['total_perc'])
    neutral = all[all['pred_gender'] == 'GENDER.neutral'].reset_index(drop=True).sort_values(by=['total_perc'])
    unknown = all[all['pred_gender'] == 'GENDER.unknown'].reset_index(drop=True).sort_values(by=['total_perc'])

    ax2.bar(x, male['total_perc'], color='#355400', label='male')
    ax2.bar(x, female['total_perc'],bottom=male['total_perc'], color='#960500', label='female')
    ax2.bar(x, unknown['total_perc'], bottom = male['total_perc']+female['total_perc'], color='#5b7a95', label='unknown')
    ax2.bar(x, neutral['total_perc'], bottom = male['total_perc']+female['total_perc']+unknown['total_perc'], color='#b1cbda', label='neutral')

    ax2.set_ylabel('Percentage in %', fontsize=15)
    ax2.xaxis.tick_top()
    ax2.set_xticks(x, grouped['ab_code'].unique(), rotation=90, fontsize=12)
    ax2.legend(title='predicted gender', loc='center left', bbox_to_anchor=(0.96, 0.5), ncol=1, framealpha=1)
    
    plt.savefig(f'../data/figures/pred_{mt}_job_stats_grouped_with_all_.png', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#                                     job_class gold_gender     pred_gender  \
# 0                                   Allgemein      female   GENDER.female
# 1                                   Allgemein      female     GENDER.male
# 2                                   Allgemein      female  GENDER.unknown
# 3                                   Allgemein        male     GENDER.male
# 4                                   Allgemein        male  GENDER.unknown
# ..                                        ...         ...             ...
# 140  Versicherungs- u. Finanzdienstleistungen        male     GENDER.male
# 141  Versicherungs- u. Finanzdienstleistungen        male  GENDER.unknown
# 142                                Verwaltung      female   GENDER.female
# 143                                Verwaltung      female     GENDER.male
# ...

# %%
import numpy as np
import pandas as pd
import re

stat = pd.read_csv('../job_data_arbeitsamt_with_short.csv')
stat['ab_code'] = stat['ab_code'].str.replace(r'(\D+)(\d+)', r'\2\1', regex=True)
stat.to_csv('./job_data_arbeitsamt_with_short.csv', index=False)

statog = pd.read_csv('./statistics_dataset/job_data_arbeitsamt_.csv')
stat['prominent_gender'] = statog.prominent_gender

stat.perc_women=stat.perc_women.round(2)
stat.perc_men = stat.perc_men.round(2)

def extract_job_title(row):
    matches = re.findall(r'\(([^,]+),', row)
    cleaned_titles = [title.strip("'") for title in matches]
    return ', '.join(cleaned_titles)

def underline_stereotype_f(row):
    if row['prominent_gender'] == 'female':
        return f'\\textit{{{row["perc_women"]}}}'
    else:
        return f'{row["perc_women"]}'
    
def underline_stereotype_m(row):
    if row['prominent_gender'] == 'male':
        return f'\\textit{{{row["perc_men"]}}}'
    else:
        return f'{row["perc_men"]}'

stat.perc_women = stat.apply(underline_stereotype_f, axis=1)
stat.perc_men = stat.apply(underline_stereotype_m, axis=1)
print(stat)

stat.to_latex('../statistics/job_stats_perc.tex', columns = ['ab_code', 'name', 'perc_women', 'perc_men'],index=False, longtable=True, float_format="%.2f", header=['Code', 'Occupational Group Name', 'Women (in \%)', 'Men in (\%)'])
stat.to_latex('../statistics/job_stats_percdf.tex', columns = ['ab_code', 'name','jobs'],index=False, longtable=True, float_format="%.2f", header=['Code', 'Occupational Group Name', 'Job Instances'])
# Out:
#    ab_code                                      name      perc_women  \
# 0        0                                 Allgemein            49.6
# 1    111Lw                            Landwirtschaft           31.48
# 2    223Ho                 Holzbe- und -verarbeitung            8.19
# 3    251Ma         Maschinenbau- und Betriebstechnik           12.33
# 4    252FL  Fahrzeug-Luft-Raumfahrt-,Schiffbautechn.            5.66
# 5    262Et                            Energietechnik            4.04
# 6    263El                            Elektrotechnik  \textit{17.69}
# 7    282Tv                        Textilverarbeitung           70.43
# 8    292Le  Lebensmittel- u. Genussmittelherstellung  \textit{32.83}
# 9    293Sp                        Speisenzubereitung           50.73
# 10   311BA   Bauplanung u. -überwachung, Architektur           30.32
# 11   321Hb                                   Hochbau            1.79
# 12   332MB  Maler.,Stuckat.,Bauwerksabd,Bautenschutz            6.46
# ...

# %%
### Vortrag

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

mt = ['bing', 'google', 'systran', 'aws']
lang = ['it', 'fr', 'uk', 'ru', 'es', 'he', 'ar']
df = pd.read_csv('pred_stats.csv')


it = df[df['stereotype'].str.contains('it', case=False)]
fr = df[df['stereotype'].str.contains('fr', case=False)]
uk = df[df['stereotype'].str.contains('uk', case=False)]
ru = df[df['stereotype'].str.contains('ru', case=False)]
es = df[df['stereotype'].str.contains('es', case=False)]

he = df[df['stereotype'].str.contains('he', case=False)]
ar = df[df['stereotype'].str.contains('ar', case=False)]

bing = df[df['stereotype'].str.contains('bing', case=False)][['f1_m','f1_f']].mean()
bing_acc = df[df['stereotype'].str.contains('bing', case=False)][['acc']].mean()
google = df[df['stereotype'].str.contains('google', case=False)][['f1_m','f1_f']].mean()
google_acc = df[df['stereotype'].str.contains('google', case=False)][['acc']].mean()
systran = df[df['stereotype'].str.contains('systran', case=False)][['f1_m','f1_f']].mean()
systran_acc = df[df['stereotype'].str.contains('systran', case=False)][['acc']].mean()
aws = df[df['stereotype'].str.contains('aws', case=False)][['f1_m','f1_f']].mean()
aws_acc = df[df['stereotype'].str.contains('aws', case=False)][['acc']].mean()
deepl = df[df['stereotype'].str.contains('deepl', case=False)][['f1_m','f1_f']].mean()
deepl_acc = df[df['stereotype'].str.contains('deepl', case=False)][['acc']].mean()

all_mt = [bing, google, systran, aws, deepl]

plt.figure(figsize=(6, 5))

# plot spanish acc
plt.bar(x=['Microsoft T.', 'Google T.', 'SYSTRAN', 'Amazon T.', 'DeepL', 'GPT-4o-mini'], height = es['acc'], width=0.75, color='cornflowerblue', edgecolor='darkblue')
#set x labels vertical
plt.xticks(rotation=750)

plt.ylabel('Accuracy in %')
plt.ylim(0,100)
#plot a horizontal line at 50%
plt.axhline(50, c='k', lw=2)

plt.legend()# Show the plot
plt.show()

plt.figure(figsize=(6, 5))

# plot all accurracies of all languages
plt.bar(x=['Spanish', 'Italian', 'French', 'Ukrainian', 'Russian', 'Hebrew', 'Arabic'], height = [es['acc'].mean(), it['acc'].mean(), fr['acc'].mean(), uk['acc'].mean(), ru['acc'].mean(), he['acc'].mean(), ar['acc'].mean()], width=0.75, color='cornflowerblue', edgecolor='darkblue')
#set x labels vertical
plt.xticks(rotation=750)
plt.ylabel('Accuracy in %')
plt.ylim(0,100)
plt.axhline(50, c='k', lw=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
df = pd.read_csv('table.csv')
print(df["delta-S_wmt"].mean())

# calculate mean of delta_g for all models

bing = df[df['stereotype'].str.contains('bing', case=False)]['delta-S_wmt'].mean()
google = df[df['stereotype'].str.contains('google', case=False)]['delta-S_wmt'].mean()
systran = df[df['stereotype'].str.contains('systran', case=False)]['delta-S_wmt'].mean()
aws = df[df['stereotype'].str.contains('aws', case=False)]['delta-S_wmt'].mean()
deepl = df[df['stereotype'].str.contains('deepl', case=False)]['delta-S_wmt'].mean()
gpt = df[df['stereotype'].str.contains('gpt4o-mini', case=False)]['delta-S_wmt'].mean()

print(bing, google, systran, aws, deepl, gpt)

gpt_acc = df[df['stereotype'].str.contains('gpt4o-mini', case=False)][['stereotype', 'acc_wo_unk', 'acc']]
print(gpt_acc)
# Out:
# 8.5125
# 12.671428571428573 12.928571428571429 5.414285714285714 12.257142857142856 5.139999999999999 1.7
#        stereotype  acc_wo_unk   acc
# 33  gpt4o-mini_it        87.4  75.5
# 34  gpt4o-mini_fr        94.9  89.4
# 35  gpt4o-mini_uk        80.7  69.6
# 36  gpt4o-mini_ru        66.5  55.4
# 37  gpt4o-mini_es        99.0  95.8
# 38  gpt4o-mini_he        84.0  78.1
# 39  gpt4o-mini_ar        88.9  83.3
